# %% [markdown]
# #**Data Preprocessing**

# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#reading the dataset
df=pd.read_csv("Dataset.csv")
df.head()
# Out:
#             Disease   Symptom_1              Symptom_2              Symptom_3
# 0  Fungal infection     itching              skin_rash   nodal_skin_eruptions  \
# 1  Fungal infection   skin_rash   nodal_skin_eruptions    dischromic _patches
# 2  Fungal infection     itching   nodal_skin_eruptions    dischromic _patches
# 3  Fungal infection     itching              skin_rash    dischromic _patches
# 4  Fungal infection     itching              skin_rash   nodal_skin_eruptions
#
#               Symptom_4 Symptom_5 Symptom_6 Symptom_7 Symptom_8 Symptom_9
# 0   dischromic _patches       NaN       NaN       NaN       NaN       NaN  \
# 1                   NaN       NaN       NaN       NaN       NaN       NaN
# 2                   NaN       NaN       NaN       NaN       NaN       NaN
# 3                   NaN       NaN       NaN       NaN       NaN       NaN
# 4                   NaN       NaN       NaN       NaN       NaN       NaN
#
#   Symptom_10 Symptom_11 Symptom_12 Symptom_13 Symptom_14 Symptom_15
# 0        NaN        NaN        NaN        NaN        NaN        NaN  \
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Symptom_16 Symptom_17
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %% [markdown]
# ## **Extracting unique Disease and Symptoms**

# %%
 #list of all disease unique
disease=list(df["Disease"].unique()) 
disease
# Out:
# ['Fungal infection',
#  'Allergy',
#  'GERD',
#  'Chronic cholestasis',
#  'Drug Reaction',
#  'Peptic ulcer diseae',
#  'AIDS',
#  'Diabetes ',
#  'Gastroenteritis',
#  'Bronchial Asthma',
#  'Hypertension ',
#  'Migraine',
#  'Cervical spondylosis',
#  'Paralysis (brain hemorrhage)',
#  'Jaundice',
#  'Malaria',
#  'Chicken pox',
#  'Dengue',
#  'Typhoid',
#  'hepatitis A',
#  'Hepatitis B',
#  'Hepatitis C',
#  'Hepatitis D',
#  'Hepatitis E',
#  'Alcoholic hepatitis',
#  'Tuberculosis',
#  'Common Cold',
#  'Pneumonia',
#  'Dimorphic hemmorhoids(piles)',
#  'Heart attack',
#  'Varicose veins',
#  'Hypothyroidism',
#  'Hyperthyroidism',
#  'Hypoglycemia',
#  'Osteoarthristis',
#  'Arthritis',
#  '(vertigo) Paroymsal  Positional Vertigo',
#  'Acne',
#  'Urinary tract infection',
#  'Psoriasis',
#  'Impetigo']

# %%
len(disease)
# Out:
# 41

# %%
symptom=df[["Symptom_1","Symptom_2","Symptom_3","Symptom_4","Symptom_5","Symptom_6","Symptom_7","Symptom_8","Symptom_9","Symptom_10","Symptom_11","Symptom_12","Symptom_13","Symptom_14","Symptom_15","Symptom_16","Symptom_17"]].stack().unique().tolist()
symptom
# Out:
# ['itching',
#  ' skin_rash',
#  ' nodal_skin_eruptions',
#  ' dischromic _patches',
#  ' continuous_sneezing',
#  ' shivering',
#  ' chills',
#  ' watering_from_eyes',
#  ' stomach_pain',
#  ' acidity',
#  ' ulcers_on_tongue',
#  ' vomiting',
#  ' cough',
#  ' chest_pain',
#  ' yellowish_skin',
#  ' nausea',
#  ' loss_of_appetite',
#  ' abdominal_pain',
#  ' yellowing_of_eyes',
#  ' burning_micturition',
#  ' spotting_ urination',
#  ' passage_of_gases',
#  ' internal_itching',
#  ' indigestion',
#  ' muscle_wasting',
#  ' patches_in_throat',
#  ' high_fever',
#  ' extra_marital_contacts',
#  ' fatigue',
#  ' weight_loss',
#  ' restlessness',
#  ' lethargy',
#  ' irregular_sugar_level',
#  ' blurred_and_distorted_vision',
#  ' obesity',
#  ' excessive_hunger',
#  ' increased_appetite',
#  ' polyuria',
#  ' sunken_eyes',
#  ' dehydration',
#  ' diarrhoea',
#  ' breathlessness',
#  ' family_history',
#  ' mucoid_sputum',
#  ' headache',
#  ' dizziness',
#  ' loss_of_balance',
#  ' lack_of_concentration',
#  ' stiff_neck',
#  ' depression',
#  ' irritability',
#  ' visual_disturbances',
#  ' back_pain',
#  ' weakness_in_limbs',
#  ' neck_pain',
#  ' weakness_of_one_body_side',
#  ' altered_sensorium',
#  ' dark_urine',
#  ' sweating',
#  ' muscle_pain',
#  ' mild_fever',
#  ' swelled_lymph_nodes',
#  ' malaise',
#  ' red_spots_over_body',
#  ' joint_pain',
#  ' pain_behind_the_eyes',
#  ' constipation',
#  ' toxic_look_(typhos)',
#  ' belly_pain',
#  ' yellow_urine',
#  ' receiving_blood_transfusion',
#  ' receiving_unsterile_injections',
#  ' coma',
#  ' stomach_bleeding',
#  ' acute_liver_failure',
#  ' swelling_of_stomach',
#  ' distention_of_abdomen',
#  ' history_of_alcohol_consumption',
#  ' fluid_overload',
#  ' phlegm',
#  ' blood_in_sputum',
#  ' throat_irritation',
#  ' redness_of_eyes',
#  ' sinus_pressure',
#  ' runny_nose',
#  ' congestion',
#  ' loss_of_smell',
#  ' fast_heart_rate',
#  ' rusty_sputum',
#  ' pain_during_bowel_movements',
#  ' pain_in_anal_region',
#  ' bloody_stool',
#  ' irritation_in_anus',
#  ' cramps',
#  ' bruising',
#  ' swollen_legs',
#  ' swollen_blood_vessels',
#  ' prominent_veins_on_calf',
#  ' weight_gain',
#  ' cold_hands_and_feets',
#  ' mood_swings',
#  ' puffy_face_and_eyes',
#  ' enlarged_thyroid',
#  ' brittle_nails',
#  ' swollen_extremeties',
#  ' abnormal_menstruation',
#  ' muscle_weakness',
#  ' anxiety',
#  ' slurred_speech',
#  ' palpitations',
#  ' drying_and_tingling_lips',
#  ' knee_pain',
#  ' hip_joint_pain',
#  ' swelling_joints',
#  ' painful_walking',
#  ' movement_stiffness',
#  ' spinning_movements',
#  ' unsteadiness',
#  ' pus_filled_pimples',
#  ' blackheads',
#  ' scurring',
#  ' bladder_discomfort',
#  ' foul_smell_of urine',
#  ' continuous_feel_of_urine',
#  ' skin_peeling',
#  ' silver_like_dusting',
#  ' small_dents_in_nails',
#  ' inflammatory_nails',
#  ' blister',
#  ' red_sore_around_nose',
#  ' yellow_crust_ooze']

# %%
len(symptom)
# Out:
# 131

# %%
df.shape
# Out:
# (4920, 18)

# %%
df.isnull().sum()
# Out:
# Disease          0
# Symptom_1        0
# Symptom_2        0
# Symptom_3        0
# Symptom_4      348
# Symptom_5     1206
# Symptom_6     1986
# Symptom_7     2652
# Symptom_8     2976
# Symptom_9     3228
# Symptom_10    3408
# Symptom_11    3726
# Symptom_12    4176
# Symptom_13    4416
# Symptom_14    4614
# Symptom_15    4680
# Symptom_16    4728
# Symptom_17    4848
# dtype: int64

# %% [markdown]
# ## **Filling NaN values**

# %%
for i in range(len(df)):
  y=df.iloc[i,1:18]                           
  v=y.mode()
  df.iloc[i,1:18].fillna(v[0],inplace=True)

# %% [markdown]
# # Data Visualization

# %%
# Defining the columns to use the scatter plot
x_columns = ["Symptom_1","Symptom_2","Symptom_3","Symptom_4","Symptom_5","Symptom_6","Symptom_7","Symptom_8","Symptom_9","Symptom_10","Symptom_11","Symptom_12","Symptom_13","Symptom_14","Symptom_15","Symptom_16","Symptom_17"]
y_column = 'Disease'

# Setting the size of the plot
fig, ax = plt.subplots(figsize=(15,15))
sns.scatterplot(data=df, x=x_columns[0], y=y_column, ax=ax)

# Adding additional scatter plots for the remaining columns
for i in range(1, len(x_columns)):
    sns.scatterplot(data=df, x=x_columns[i], y=y_column, ax=ax)

# %% [markdown]
# # Implementing Naive Bayes (GaussianNB) and KNN

# %%
# importing relevant libraries
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
# splitting the dataset with 79% for training and 25% for testing
X=df.iloc[:,1:]
y=df.iloc[:,0]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %% [markdown]
# **LABEL ENCODING**

# %%
# importing library and label encoding using .fit_transform
from sklearn.preprocessing import LabelEncoder
la=LabelEncoder()
X_train=X_train.apply(LabelEncoder().fit_transform)
X_test=X_test.apply(LabelEncoder().fit_transform)

# %% [markdown]
# **GaussianNB**

# %%
#implementing Gaussian NB model
nb=GaussianNB()
nb.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
#making predictions
y_pred=nb.predict(X_test)

# %%
#function to predict the disease
def model(a=-1,b=-1,c=-1,d=-1,e=-1,f=-1,g=-1,h=-1,i=-1,j=-1,k=-1,l=-1,m=-1,n=-1,s=-1,w=-1,u=-1):
  predicted_label = nb.predict([[a,b,c,d,e,f,g,h,i,j,k,l,m,n,s,w,u]])[0]
  print(predicted_label)
  
#symptoms
model(2,7,4,0,51,57,32)
# Out:
# Hepatitis D
# /home/mehbub17/.local/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## **KNN**

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh=KNeighborsClassifier(n_neighbors=32)
neigh.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=32)

# %%
ypredknn=neigh.predict(X_test)

# %%
def knnmodel(a=-1,b=-1,c=-1,d=-1,e=-1,f=-1,g=-1,h=-1,i=-1,j=-1,k=-1,l=-1,m=-1,n=-1,s=-1,w=-1,u=-1):
  v=neigh.predict([[a,b,c,d,e,f,g,h,i,j,k,l,m,n,s,w,u]])
  print(v)

knnmodel(2,7,4,0,51)
# Out:
# ['Bronchial Asthma']
# /home/mehbub17/.local/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # PERFORMANCE METRICS

# %% [markdown]
# ##**F1, Recall, Precision, Accuracy, Heatmap & Confusion Matrix  of GaussianNB**

# %%
# Evaluate the performance of the model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro')
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')

# %%
print("Accuracy: {:.2f}%".format(accuracy * 100))
print("Precision: {:.2f}%".format(precision * 100))
print("Recall: {:.2f}%".format(recall * 100))
print("F1 Score: {:.2f}%".format(f1 * 100))
# Out:
# Accuracy: 83.74%
# Precision: 88.33%
# Recall: 83.60%
# F1 Score: 81.41%

# %% [markdown]
# **HEATMAP**

# %%
from sklearn.metrics import confusion_matrix
from sklearn import metrics

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[21,  0,  0, ...,  0,  0,  0],
#        [ 4, 32,  0, ...,  0,  0,  0],
#        [ 0,  0,  2, ...,  0,  0,  0],
#        ...,
#        [ 0,  0,  0, ..., 33,  0,  0],
#        [ 0,  0,  0, ...,  0, 27,  0],
#        [ 0,  0,  0, ...,  0,  0, 30]])

# %%
sns.heatmap(data=cm)
# Out:
# <Axes: >

# %% [markdown]
# **CONFUSION MATRIX**

# %%
from sklearn.metrics import confusion_matrix
k=y_test
print(metrics.confusion_matrix(k,y_pred))
print(metrics.classification_report(k,y_pred))
# Out:
# [[21  0  0 ...  0  0  0]
#  [ 4 32  0 ...  0  0  0]
#  [ 0  0  2 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 33  0  0]
#  [ 0  0  0 ...  0 27  0]
#  [ 0  0  0 ...  0  0 30]]
#                                          precision    recall  f1-score   support
#
# (vertigo) Paroymsal  Positional Vertigo       0.39      0.91      0.55        23
#                                    AIDS       1.00      0.89      0.94        36
#                                    Acne       0.29      0.06      0.10        33
#                     Alcoholic hepatitis       1.00      1.00      1.00        29
#                                 Allergy       0.72      0.90      0.80        29
#                               Arthritis       1.00      0.13      0.24        30
#                        Bronchial Asthma       1.00      0.97      0.99        38
#                    Cervical spondylosis       0.84      0.90      0.87        29
#                             Chicken pox       1.00      0.03      0.06        30
#                     Chronic cholestasis       1.00      0.76      0.86        21
#                             Common Cold       1.00      1.00      1.00        29
#                                  Dengue       1.00      1.00      1.00        29
#                               Diabetes        1.00      1.00      1.00        29
#            Dimorphic hemmorhoids(piles)       1.00      0.86      0.93        37
#                           Drug Reaction       0.39      0.90      0.54        30
#                        Fungal infection       0.42      0.87      0.56        23
#                                    GERD       1.00      0.95      0.97        37
#                         Gastroenteritis       1.00      0.91      0.95        33
#                            Heart attack       0.93      0.90      0.92        31
#                             Hepatitis B       1.00      1.00      1.00        38
#                             Hepatitis C       1.00      0.91      0.95        32
#                             Hepatitis D       0.82      0.33      0.47        27
#                             Hepatitis E       0.64      1.00      0.78        39
#                           Hypertension        0.96      0.85      0.90        26
#                         Hyperthyroidism       1.00      1.00      1.00        26
#                            Hypoglycemia       1.00      1.00      1.00        32
#                          Hypothyroidism       1.00      1.00      1.00        30
#                                Impetigo       0.46      0.80      0.59        30
#                                Jaundice       0.87      0.93      0.90        28
#                                 Malaria       0.78      1.00      0.88        25
#                                Migraine       1.00      0.91      0.95        32
#                         Osteoarthristis       1.00      0.96      0.98        23
#            Paralysis (brain hemorrhage)       0.80      0.97      0.88        29
#                     Peptic ulcer diseae       1.00      0.95      0.98        21
#                               Pneumonia       0.92      1.00      0.96        34
#                               Psoriasis       1.00      0.03      0.07        29
#                            Tuberculosis       1.00      1.00      1.00        30
#                                 Typhoid       1.00      0.92      0.96        25
#                 Urinary tract infection       1.00      1.00      1.00        33
#                          Varicose veins       1.00      0.96      0.98        28
#                             hepatitis A       1.00      0.81      0.90        37
#
#                                accuracy                           0.84      1230
#                               macro avg       0.88      0.84      0.81      1230
#                            weighted avg       0.89      0.84      0.82      1230

# %% [markdown]
# ## **F1,Recall,Precision,Accuracy,Confusion matrix,Heatmap of KNN**

# %%
accuracyknn = accuracy_score(y_test, ypredknn)
precisionknn = precision_score(y_test, ypredknn, average='macro')
recallknn = recall_score(y_test, ypredknn, average='macro')
f1knn = f1_score(y_test, ypredknn, average='macro')

# %%
print("Accuracy: {:.2f}%".format(accuracyknn * 100))
print("Precision: {:.2f}%".format(precisionknn * 100))
print("Recall: {:.2f}%".format(recallknn * 100))
print("F1 Score: {:.2f}%".format(f1knn * 100))
# Out:
# Accuracy: 93.01%
# Precision: 93.61%
# Recall: 93.33%
# F1 Score: 93.18%

# %%
kn=y_test
print(metrics.confusion_matrix(k,ypredknn))
print(metrics.classification_report(k,ypredknn))
# Out:
# [[19  0  0 ...  0  0  0]
#  [ 0 36  0 ...  0  0  0]
#  [ 0  0 26 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 33  0  0]
#  [ 0  0  0 ...  0 28  0]
#  [ 0  0  0 ...  0  0 28]]
#                                          precision    recall  f1-score   support
#
# (vertigo) Paroymsal  Positional Vertigo       1.00      0.83      0.90        23
#                                    AIDS       0.92      1.00      0.96        36
#                                    Acne       0.65      0.79      0.71        33
#                     Alcoholic hepatitis       0.96      0.93      0.95        29
#                                 Allergy       0.93      0.86      0.89        29
#                               Arthritis       0.88      1.00      0.94        30
#                        Bronchial Asthma       1.00      0.79      0.88        38
#                    Cervical spondylosis       0.93      0.90      0.91        29
#                             Chicken pox       0.94      1.00      0.97        30
#                     Chronic cholestasis       1.00      0.95      0.98        21
#                             Common Cold       0.94      1.00      0.97        29
#                                  Dengue       1.00      1.00      1.00        29
#                               Diabetes        1.00      0.97      0.98        29
#            Dimorphic hemmorhoids(piles)       0.76      0.86      0.81        37
#                           Drug Reaction       0.93      0.87      0.90        30
#                        Fungal infection       0.87      0.87      0.87        23
#                                    GERD       0.93      0.73      0.82        37
#                         Gastroenteritis       1.00      1.00      1.00        33
#                            Heart attack       0.77      0.87      0.82        31
#                             Hepatitis B       1.00      0.95      0.97        38
#                             Hepatitis C       0.91      0.94      0.92        32
#                             Hepatitis D       1.00      0.93      0.96        27
#                             Hepatitis E       1.00      0.95      0.97        39
#                           Hypertension        0.93      0.96      0.94        26
#                         Hyperthyroidism       0.79      1.00      0.88        26
#                            Hypoglycemia       1.00      1.00      1.00        32
#                          Hypothyroidism       0.94      1.00      0.97        30
#                                Impetigo       1.00      0.90      0.95        30
#                                Jaundice       1.00      0.82      0.90        28
#                                 Malaria       0.89      1.00      0.94        25
#                                Migraine       1.00      1.00      1.00        32
#                         Osteoarthristis       0.92      1.00      0.96        23
#            Paralysis (brain hemorrhage)       0.90      0.97      0.93        29
#                     Peptic ulcer diseae       0.87      0.95      0.91        21
#                               Pneumonia       1.00      1.00      1.00        34
#                               Psoriasis       0.85      1.00      0.92        29
#                            Tuberculosis       1.00      0.93      0.97        30
#                                 Typhoid       1.00      1.00      1.00        25
#                 Urinary tract infection       0.97      1.00      0.99        33
#                          Varicose veins       1.00      1.00      1.00        28
#                             hepatitis A       1.00      0.76      0.86        37
#
#                                accuracy                           0.93      1230
#                               macro avg       0.94      0.93      0.93      1230
#                            weighted avg       0.94      0.93      0.93      1230

# %%
kncm = confusion_matrix(y_test[0:1034], ypredknn)
sns.heatmap(data=kncm)
# Out:
# <Axes: >

# %% [markdown]
# ##**Comparative analysis between KNN and Gaussian(F1,Recall,Precision,Accuracy)**

# %%
import numpy as np
knnlis=[90.23,91.03,90.48,90.13]
gua=[88.20,91.00,87.93,88.35]
x = np.arange(4)
width = 0.40
plt.bar(x-0.2, knnlis, width,color="Red")
plt.bar(x+0.2, gua, width,color="Blue")
plt.xticks(x,["Accuracy","Precision","Recall","F1-Score"])
# Out:
# ([<matplotlib.axis.XTick at 0x7f71ccd30df0>,
#   <matplotlib.axis.XTick at 0x7f71ccd30280>,
#   <matplotlib.axis.XTick at 0x7f71ccd30ca0>,
#   <matplotlib.axis.XTick at 0x7f71cccc8880>],
#  [Text(0, 0, 'Accuracy'),
#   Text(1, 0, 'Precision'),
#   Text(2, 0, 'Recall'),
#   Text(3, 0, 'F1-Score')])

# %% [markdown]
# ## **Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
y_predd = clf.predict(X_test)
accuracyd = accuracy_score(y_test, y_predd)
precisiond = precision_score(y_test, y_predd, average='weighted')
recalld = recall_score(y_test, y_predd, average='macro')
f1 = f1_score(y_test, y_predd, average='macro')

print("Accuracy: {:.2f}%".format(accuracyd * 100))
print("Precision: {:.2f}%".format(precisiond * 100))
print("Recall: {:.2f}%".format(recalld * 100))
print("F1 Score: {:.2f}%".format(f1*100))
# Out:
# Accuracy: 86.59%
# Precision: 87.80%
# Recall: 85.20%
# F1 Score: 82.25%
